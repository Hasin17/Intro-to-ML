# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')

url = '/content/drive/My Drive/Course Fall 24/Intro to ML/Assignment 1/D3.csv'
df = pd.read_csv(url)
print(df.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#          X1        X2        X3         Y
# 0  0.000000  3.440000  0.440000  4.387545
# 1  0.040404  0.134949  0.888485  2.679650
# 2  0.080808  0.829899  1.336970  2.968490
# 3  0.121212  1.524848  1.785455  3.254065
# 4  0.161616  2.219798  2.233939  3.536375

# %%
X1 = df.values[:, 0]
X2 = df.values[:, 1]
X3 = df.values[:, 2]
y = df.values[:, 3]
p = len(y)
q = len(X1)
r = len(X2)
s = len(X3)

print('X1 = ', X1[: 5])
print('X2 = ', X2[: 5])
print('X3 = ', X3[: 5])
print('y = ', y[: 5])
print('p = ', p)
print('q = ', q)
print('r = ', r)
print('s = ', s)
# Out:
# X1 =  [0.         0.04040404 0.08080808 0.12121212 0.16161616]
# X2 =  [3.44       0.1349495  0.82989899 1.52484848 2.21979798]
# X3 =  [0.44       0.88848485 1.3369697  1.78545454 2.23393939]
# y =  [4.38754501 2.6796499  2.96848981 3.25406475 3.53637472]
# p =  100
# q =  100
# r =  100
# s =  100

# %%
plt.scatter(X1, y, color='red', marker='+')
plt.scatter(X2, y, color='blue', marker='+')
plt.scatter(X3, y, color='green', marker='+')

# %%
X_0 = np.ones((q, 1))
X_1 = X1.reshape(q, 1)
XX1 = np.hstack((X_0, X_1))
X_2 = X2.reshape(r, 1)
XX2 = np.hstack((X_0, X_2))
X_3 = X3.reshape(s, 1)
XX3 = np.hstack((X_0, X_3))
w = np.zeros(2)
w
# Out:
# array([0., 0.])

# %%
def loss_func(X, y, w, n):

    loss = X.dot(w)
    diff = np.subtract(loss, y)
    sqrDiff = np.square(diff)
    L = 1 / (2 * n) * np.sum(sqrDiff)
    return L

# %%
loss = loss_func(XX1, y, w, q)
print('The cost  =', loss)
# Out:
# The cost  = 5.524438459196242

# %%
def gradient_descent(X, y, w, alpha, iter):

    p = len(y)  # Number of training examples
    loss_history = np.zeros(iter)

    for i in range(iter):
        loss = X.dot(w)
        diff = np.subtract(loss, y)
        sum_delta = (alpha / p) * X.transpose().dot(diff)
        w -= sum_delta
        loss_history[i] = loss_func(X, y, w, p)

    return w, loss_history

# %%
w0 = [0., 0.]
iterations = 1500
alpha_1 = 0.01
alpha_2 = 0.07
w, loss_history = gradient_descent(XX1, y, w0, alpha_1, iterations)
w1, loss_history1 = gradient_descent(XX1, y, w0, alpha_2, iterations)
print('Final value of w =', w)
print('loss_history =', loss_history)
plt.plot(range(1, iterations + 1), loss_history, color='blue')
plt.plot(range(1, iterations + 1), loss_history1, color='red')
plt.grid(True)
# Out:
# Final value of w = [ 5.71850653 -1.9568206 ]
# loss_history = [5.48226715 5.44290965 5.40604087 ... 0.99063932 0.99061433 0.99058944]

# %%
plt.scatter(XX1[:, 1], y, color='red', marker='+')
plt.plot(XX1[:, 1], XX1.dot(w), color='green')

# %%
w0 = [0., 0.]
iterations = 1500
alpha_1 = 0.01
alpha_2 = 0.07
w, loss_history = gradient_descent(XX2, y, w0, alpha_1, iterations)
w1, loss_history1 = gradient_descent(XX2, y, w0, alpha_2, iterations)
print('Final value of w =', w)
print('loss_history =', loss_history)
plt.plot(range(1, iterations + 1), loss_history, color='blue')
plt.plot(range(1, iterations + 1), loss_history1, color='red')
plt.grid(True)
# Out:
# Final value of w = [0.71988473 0.56390334]
# loss_history = [5.29831663 5.09909109 4.92356115 ... 3.5993997  3.59939955 3.5993994 ]

# %%
plt.scatter(XX2[:, 1], y, color='red', marker='+')
plt.plot(XX2[:, 1], XX2.dot(w), color='green')

# %%
w0 = [0., 0.]
iterations = 1500
alpha_1 = 0.01
alpha_2 = 0.07
w, loss_history = gradient_descent(XX3, y, w0, alpha_1, iterations)
w1, loss_history1 = gradient_descent(XX3, y, w0, alpha_2, iterations)
print('Final value of w =', w)
print('loss_history =', loss_history)
plt.plot(range(1, iterations + 1), loss_history, color='blue')
plt.plot(range(1, iterations + 1), loss_history1, color='red')
plt.grid(True)
# Out:
# Final value of w = [ 2.78048129 -0.48451631]
# loss_history = [5.40768785 5.30397076 5.21178297 ... 3.63053597 3.6305311  3.63052625]

# %%
plt.scatter(XX3[:, 1], y, color='red', marker='+')
plt.plot(XX3[:, 1], XX3.dot(w), color='green')
